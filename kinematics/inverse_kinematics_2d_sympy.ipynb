# %% [markdown]
# # Inverse Kinematics (2D)

# %%
from __future__ import division
# %matplotlib notebook
from matplotlib import pylab as plt
from numpy import sin, cos, pi, matrix, random
from math import atan2
from IPython import display
from ipywidgets import interact, fixed

# %% [markdown]
# ## Coordinate Transformation

# %%
def trans(x, y, a):
    '''create a 2D transformation'''
    s = sin(a)
    c = cos(a)
    return matrix([[c, -s, x],
                   [s,  c, y],
                   [0,  0, 1]])

def from_trans(m):
    '''get x, y, theta from transform matrix'''
    return [m[0, -1], m[1, -1], atan2(m[1, 0], m[0, 0])]

# %%
M = trans(1, 2, 3)
print(from_trans(M))
# Out:
# [1.0, 2.0, 3.0]

# %% [markdown]
# ## Parameters of robot arm

# %%
N = 3  # number of links

l = [0] + list(range(N, 0, -1))  # length of link, l[0] is ingored
print("l=", l)
max_len = sum(l)
print("max_len=", max_len)
a = random.random_sample(N)  # angles of joints
T0 = trans(0, 0, 0)  # base
# Out:
# l= [0, 3, 2, 1]
# max_len= 6

# %% [markdown]
# ## Forward Kinematics

# %%
def forward_kinematics(T0, l, a):
    T = [T0]
    for i in range(len(a)):
        Ti = T[-1] * trans(l[i], 0, a[i])
        T.append(Ti)
    Te = T[-1] * trans(l[-1], 0, 0)  # end effector
    T.append(Te)
    return T

# %%
def show_robot_arm(T):
    plt.cla()
    x = [Ti[0,-1] for Ti in T]
    y = [Ti[1,-1] for Ti in T]
    plt.plot(x, y, '-or', linewidth=5, markersize=10)
    plt.plot(x[-1], y[-1], 'og', linewidth=5, markersize=10)
    plt.xlim([-max_len, max_len])
    plt.ylim([-max_len, max_len]) 
    ax = plt.axes()
    ax.set_aspect('equal')
    t = atan2(T[-1][1, 0], T[-1][0,0])
    ax.annotate('[%.2f,%.2f,%.2f]' % (x[-1], y[-1], t), xy=(x[-1], y[-1]), xytext=(x[-1], y[-1] + 0.5))
    plt.show()

# %% [markdown]
# ## Inverse Kinematics

# %% [markdown]
# ## Analytical Solutions with Sympy

# %% [markdown]
# [SymPy](http://sympy.org/) is a Python library for symbolic mathematics.

# %%
from sympy import init_printing, sin, cos, pi, asin, acos, atan2, atan, sqrt, simplify, solve, latex, symbols
from sympy import Matrix as matrix
init_printing()

# %%
from sympy.abc import x, y, theta
trans(x, y, theta)
# Out:
# ⎡cos(θ)  -sin(θ)  x⎤
# ⎢                  ⎥
# ⎢sin(θ)  cos(θ)   y⎥
# ⎢                  ⎥
# ⎣  0        0     1⎦

# %%
N = 3
l = [symbols('l_%d' % i) for i in range(N + 1)]
l[0] = 0
print("l=",l)
a = [symbols('theta_%d' % i) for i in range(N)]
print("a=",a)
T0 = trans(0, 0, 0)
# Out:
# l= [0, l_1, l_2, l_3]
# a= [theta_0, theta_1, theta_2]

# %%
l, a
# Out:
# ([0, l₁, l₂, l₃], [θ₀, θ₁, θ₂])

# %%
T0
# Out:
# ⎡1  0  0⎤
# ⎢       ⎥
# ⎢0  1  0⎥
# ⎢       ⎥
# ⎣0  0  1⎦

# %%
T = forward_kinematics(T0, l, a)
Te = T[-1]
Te
# Out:
# ⎡(-sin(θ₀)⋅sin(θ₁) + cos(θ₀)⋅cos(θ₁))⋅cos(θ₂) + (-sin(θ₀)⋅cos(θ₁) - sin(θ₁)⋅co
# ⎢
# ⎢(-sin(θ₀)⋅sin(θ₁) + cos(θ₀)⋅cos(θ₁))⋅sin(θ₂) + (sin(θ₀)⋅cos(θ₁) + sin(θ₁)⋅cos
# ⎢
# ⎣                                             0
#
# s(θ₀))⋅sin(θ₂)  -(-sin(θ₀)⋅sin(θ₁) + cos(θ₀)⋅cos(θ₁))⋅sin(θ₂) + (-sin(θ₀)⋅cos(
#
# (θ₀))⋅cos(θ₂)    (-sin(θ₀)⋅sin(θ₁) + cos(θ₀)⋅cos(θ₁))⋅cos(θ₂) - (sin(θ₀)⋅cos(θ
#
#                                                              0
#
# θ₁) - sin(θ₁)⋅cos(θ₀))⋅cos(θ₂)  l₁⋅cos(θ₀) + l₂⋅(-sin(θ₀)⋅sin(θ₁) + cos(θ₀)⋅co
#
# ₁) + sin(θ₁)⋅cos(θ₀))⋅sin(θ₂)    l₁⋅sin(θ₀) + l₂⋅(sin(θ₀)⋅cos(θ₁) + sin(θ₁)⋅co
#
#
#
# s(θ₁)) + l₃⋅((-sin(θ₀)⋅sin(θ₁) + cos(θ₀)⋅cos(θ₁))⋅cos(θ₂) + (-sin(θ₀)⋅cos(θ₁)
#
# s(θ₀)) + l₃⋅((-sin(θ₀)⋅sin(θ₁) + cos(θ₀)⋅cos(θ₁))⋅sin(θ₂) + (sin(θ₀)⋅cos(θ₁) +
#
#                              1
#
# - sin(θ₁)⋅cos(θ₀))⋅sin(θ₂))⎤
#                            ⎥
#  sin(θ₁)⋅cos(θ₀))⋅cos(θ₂)) ⎥
#                            ⎥
#                            ⎦

# %%
Te = simplify(Te)
Te
# Out:
# ⎡cos(θ₀ + θ₁ + θ₂)  -sin(θ₀ + θ₁ + θ₂)  l₁⋅cos(θ₀) + l₂⋅cos(θ₀ + θ₁) + l₃⋅cos(
# ⎢
# ⎢sin(θ₀ + θ₁ + θ₂)  cos(θ₀ + θ₁ + θ₂)   l₁⋅sin(θ₀) + l₂⋅sin(θ₀ + θ₁) + l₃⋅sin(
# ⎢
# ⎣        0                  0                                    1
#
# θ₀ + θ₁ + θ₂)⎤
#              ⎥
# θ₀ + θ₁ + θ₂)⎥
#              ⎥
#              ⎦

# %%
# Te = T0 * trans(x, y, theta)
# T0 * trans(x, y, theta) - Te = 0
# Te * trans(x, y, theta).inv() - T0 = 0
eq = Te * trans(x, y, theta).inv() - T0
eq
# Out:
# ⎡⎛     2            ⎞
# ⎢⎜  sin (θ)     1   ⎟
# ⎢⎜- ─────── + ──────⎟⋅cos(θ₀ + θ₁ + θ₂) + sin(θ)⋅sin(θ₀ + θ₁ + θ₂) - 1    sin(
# ⎢⎝   cos(θ)   cos(θ)⎠
# ⎢
# ⎢  ⎛     2            ⎞
# ⎢  ⎜  sin (θ)     1   ⎟
# ⎢  ⎜- ─────── + ──────⎟⋅sin(θ₀ + θ₁ + θ₂) - sin(θ)⋅cos(θ₀ + θ₁ + θ₂)    sin(θ)
# ⎢  ⎝   cos(θ)   cos(θ)⎠
# ⎢
# ⎣                                  0
#
#
#
# θ)⋅cos(θ₀ + θ₁ + θ₂) - sin(θ₀ + θ₁ + θ₂)⋅cos(θ)    l₁⋅cos(θ₀) + l₂⋅cos(θ₀ + θ₁
#
#
#
#
# ⋅sin(θ₀ + θ₁ + θ₂) + cos(θ)⋅cos(θ₀ + θ₁ + θ₂) - 1  l₁⋅sin(θ₀) + l₂⋅sin(θ₀ + θ₁
#
#
#                      0
#
#                                                                      ⎛     2
#                                                                      ⎝x⋅sin (θ
# ) + l₃⋅cos(θ₀ + θ₁ + θ₂) - (x⋅sin(θ) - y⋅cos(θ))⋅sin(θ₀ + θ₁ + θ₂) + ─────────
#
#
#                                                                      ⎛     2
#                                                                      ⎝x⋅sin (θ
# ) + l₃⋅sin(θ₀ + θ₁ + θ₂) + (x⋅sin(θ) - y⋅cos(θ))⋅cos(θ₀ + θ₁ + θ₂) + ─────────
#
#
#                                               0
#
#                        ⎞                  ⎤
# ) - x - y⋅sin(θ)⋅cos(θ)⎠⋅cos(θ₀ + θ₁ + θ₂)⎥
# ──────────────────────────────────────────⎥
#               cos(θ)                      ⎥
#                                           ⎥
#                        ⎞                  ⎥
# ) - x - y⋅sin(θ)⋅cos(θ)⎠⋅sin(θ₀ + θ₁ + θ₂)⎥
# ──────────────────────────────────────────⎥
#               cos(θ)                      ⎥
#                                           ⎥
#                                           ⎦

# %%
eq = [a[0] + a[1] + a[2] - theta, eq[0, 2], eq[1, 2]]
eq
# Out:
# ⎡
# ⎢
# ⎢-θ + θ₀ + θ₁ + θ₂, l₁⋅cos(θ₀) + l₂⋅cos(θ₀ + θ₁) + l₃⋅cos(θ₀ + θ₁ + θ₂) - (x⋅s
# ⎣
#
#                                       ⎛     2                         ⎞
#                                       ⎝x⋅sin (θ) - x - y⋅sin(θ)⋅cos(θ)⎠⋅cos(θ₀
# in(θ) - y⋅cos(θ))⋅sin(θ₀ + θ₁ + θ₂) + ────────────────────────────────────────
#                                                              cos(θ)
#
#
#  + θ₁ + θ₂)
# ───────────, l₁⋅sin(θ₀) + l₂⋅sin(θ₀ + θ₁) + l₃⋅sin(θ₀ + θ₁ + θ₂) + (x⋅sin(θ) -
#
#
#                                ⎛     2                         ⎞
#                                ⎝x⋅sin (θ) - x - y⋅sin(θ)⋅cos(θ)⎠⋅sin(θ₀ + θ₁ +
#  y⋅cos(θ))⋅cos(θ₀ + θ₁ + θ₂) + ───────────────────────────────────────────────
#                                                       cos(θ)
#
#     ⎤
#  θ₂)⎥
# ────⎥
#     ⎦

# %%
solve(eq, a)  # sympy is too stupid to solve it
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4768\4178578831.py in <module>
# ----> 1 solve(eq, a)  # sympy is too stupid to solve it
#
# c:\program files\python37\lib\site-packages\sympy\solvers\solvers.py in solve(f, *symbols, **flags)
#    1106         solution = _solve(f[0], *symbols, **flags)
#    1107     else:
# -> 1108         solution = _solve_system(f, symbols, **flags)
#    1109
#    1110     #
#
# c:\program files\python37\lib\site-packages\sympy\solvers\solvers.py in _solve_system(exprs, symbols, **flags)
#    1942                 for s in ok_syms:
#    1943                     try:
# -> 1944                         soln = _solve(eq2, s, **flags)
#    1945                     except NotImplementedError:
#    1946                         continue
#
# c:\program files\python37\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1554                         # solutions in the un-rewritten form below
#    1555                         flags['check'] = False
# -> 1556                         result = _solve(newf, symbol, **flags)
#    1557                         flags['check'] = check
#    1558
#
# c:\program files\python37\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1710         flags.pop('tsolve', None)  # allow tsolve to be used on next pass
#    1711         try:
# -> 1712             soln = _tsolve(f_num, symbol, **flags)
#    1713             if soln is not None:
#    1714                 result = soln
#
# c:\program files\python37\lib\site-packages\sympy\solvers\solvers.py in _tsolve(eq, sym, **flags)
#    2564             f = factor(powdenest(lhs - rhs))
#    2565             if f.is_Mul:
# -> 2566                 return _solve(f, sym, **flags)
#    2567             if rhs:
#    2568                 f = logcombine(lhs, force=flags.get('force', True))
#
# c:\program files\python37\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1392                 result = set()
#    1393                 break
# -> 1394             soln = _solve(m, symbol, **flags)
#    1395             result.update(set(soln))
#    1396         result = list(result)
#
# c:\program files\python37\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1710         flags.pop('tsolve', None)  # allow tsolve to be used on next pass
#    1711         try:
# -> 1712             soln = _tsolve(f_num, symbol, **flags)
#    1713             if soln is not None:
#    1714                 result = soln
#
# c:\program files\python37\lib\site-packages\sympy\solvers\solvers.py in _tsolve(eq, sym, **flags)
#    2683         rewrite = lhs.rewrite(exp)
#    2684         if rewrite != lhs:
# -> 2685             return _solve(rewrite - rhs, sym, **flags)
#    2686     except NotImplementedError:
#    2687         pass
#
# c:\program files\python37\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1484         try:
#    1485             if poly is None:
# -> 1486                 poly = Poly(f_num)
#    1487             if poly is None:
#    1488                 raise ValueError('could not convert %s to Poly' % f_num)
#
# c:\program files\python37\lib\site-packages\sympy\polys\polytools.py in __new__(cls, rep, *gens, **args)
#     179                 return cls._from_poly(rep, opt)
#     180             else:
# --> 181                 return cls._from_expr(rep, opt)
#     182
#     183     # Poly does not pass its args to Basic.__new__ to be stored in _args so we
#
# c:\program files\python37\lib\site-packages\sympy\polys\polytools.py in _from_expr(cls, rep, opt)
#     308     def _from_expr(cls, rep, opt):
#     309         """Construct a polynomial from an expression. """
# --> 310         rep, opt = _dict_from_expr(rep, opt)
#     311         return cls._from_dict(rep, opt)
#     312
#
# c:\program files\python37\lib\site-packages\sympy\polys\polyutils.py in _dict_from_expr(expr, opt)
#     355         if not isinstance(expr, (Expr, Eq)):
#     356             raise PolynomialError('expression must be of type Expr')
# --> 357         expr = expr.expand()
#     358         # TODO: Integrate this into expand() itself
#     359         while any(_is_expandable_pow(i) or i.is_Mul and
#
# c:\program files\python37\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      68         def wrapper(*args, **kwargs):
#      69             try:
# ---> 70                 retval = cfunc(*args, **kwargs)
#      71             except TypeError as e:
#      72                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# c:\program files\python37\lib\site-packages\sympy\core\expr.py in expand(self, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    3622             if use_hint:
#    3623                 hint = '_eval_expand_' + hint
# -> 3624                 expr, hit = Expr._expand_hint(expr, hint, deep=deep, **hints)
#    3625
#    3626         while True:
#
# c:\program files\python37\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    3555             sargs = []
#    3556             for arg in expr.args:
# -> 3557                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3558                 hit |= arghit
#    3559                 sargs.append(arg)
#
# c:\program files\python37\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    3563
#    3564         if hasattr(expr, hint):
# -> 3565             newexpr = getattr(expr, hint)(**hints)
#    3566             if newexpr != expr:
#    3567                 return (newexpr, True)
#
# c:\program files\python37\lib\site-packages\sympy\core\mul.py in _eval_expand_mul(self, **hints)
#     975                 args = []
#     976                 for term in terms:
# --> 977                     t = self.func(plain, term)
#     978                     if t.is_Mul and any(a.is_Add for a in t.args) and deep:
#     979                         t = t._eval_expand_mul()
#
# c:\program files\python37\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      68         def wrapper(*args, **kwargs):
#      69             try:
# ---> 70                 retval = cfunc(*args, **kwargs)
#      71             except TypeError as e:
#      72                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# c:\program files\python37\lib\site-packages\sympy\core\operations.py in __new__(cls, evaluate, _sympify, *args)
#      96             return args[0]
#      97
# ---> 98         c_part, nc_part, order_symbols = cls.flatten(args)
#      99         is_commutative = not nc_part
#     100         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# c:\program files\python37\lib\site-packages\sympy\core\mul.py in flatten(cls, seq)
#     363                     return [S.NaN], [], None
#     364                 elif coeff.is_Number or isinstance(coeff, AccumBounds):  # it could be zoo
# --> 365                     coeff *= o
#     366                     if coeff is S.NaN:
#     367                         # we know for sure the result will be nan
#
# c:\program files\python37\lib\site-packages\sympy\core\numbers.py in __mul__(self, other)
#    2205                 return Integer(self.p*other)
#    2206             elif isinstance(other, Integer):
# -> 2207                 return Integer(self.p*other.p)
#    2208             elif isinstance(other, Rational):
#    2209                 return Rational(self.p*other.p, other.q, igcd(self.p, other.q))
#
# c:\program files\python37\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      68         def wrapper(*args, **kwargs):
#      69             try:
# ---> 70                 retval = cfunc(*args, **kwargs)
#      71             except TypeError as e:
#      72                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# KeyboardInterrupt:

# %% [markdown]
# ### cosine rule

# %%
# now we use cosine rule to solve the equation

b = [symbols('theta_%d' % i) for i in range(N)]  # target angles
T3 = trans(x, y, theta) * trans(l[3], 0, 0).inv()
l_1_2 = T3[0,-1] ** 2 + T3[1,-1] ** 2
b_1_2 = acos((l[1] ** 2 + l[2] ** 2 - l_1_2) / (2 * l[1] * l[2]))  # cosine rule
b[1] = pi - b_1_2
b_1 = acos((l[1] ** 2 - l[2] ** 2 + l_1_2) / (2 * l[1] * sqrt(l_1_2)))  # cosine rule
b_0 = atan(T3[1,-1] / T3[0,-1])
b[0] = b_0 - b_1
b[2] = atan(T3[1,0] / T3[0,0]) - b[0] - b[1]
B = matrix([b]).T
B = simplify(B)
B  # vector of target angles, e.g. [theta_0, theta_1, theta_2]
# Out:
# ⎡                                             ⎛  2     2                  2
# ⎢                                             ⎜l₁  - l₂  + (l₃⋅sin(θ) - y)  +
# ⎢                                       - acos⎜───────────────────────────────
# ⎢                                             ⎜         ______________________
# ⎢                                             ⎜        ╱                2
# ⎢                                             ⎝ 2⋅l₁⋅╲╱  (l₃⋅sin(θ) - y)  + (l
# ⎢
# ⎢                                                         ⎛  2     2
# ⎢                                                         ⎜l₁  + l₂  - (l₃⋅sin
# ⎢                                                 π - acos⎜───────────────────
# ⎢                                                         ⎝
# ⎢
# ⎢    ⎛  2     2                   2                   2⎞       ⎛  2     2
# ⎢    ⎜l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-
# ⎢acos⎜─────────────────────────────────────────────────⎟ + acos⎜──────────────
# ⎢    ⎝                     2⋅l₁⋅l₂                     ⎠       ⎜         _____
# ⎢                                                              ⎜        ╱
# ⎣                                                              ⎝ 2⋅l₁⋅╲╱  (-l₃
#
#                2⎞
# (l₃⋅cos(θ) - x) ⎟       ⎛l₃⋅sin(θ) - y⎞
# ────────────────⎟ + atan⎜─────────────⎟
# _______________ ⎟       ⎝l₃⋅cos(θ) - x⎠
#              2  ⎟
# ₃⋅cos(θ) - x)   ⎠
#
#         2                  2⎞
# (θ) - y)  - (l₃⋅cos(θ) - x) ⎟
# ────────────────────────────⎟
#  2⋅l₁⋅l₂                    ⎠
#
#               2                   2⎞
# l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞
# ───────────────────────────────────⎟ - atan⎜──────────────⎟ + atan(tan(θ)) - π
# __________________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠
#             2                   2  ⎟
# ⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
#
# ⎤
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎦

# %%
# print latex(B)

# %%
# validate the results by forward kinematics

T_new = forward_kinematics(T0, l, b)
Te_new = T_new[-1]
Te_new  # should be same as Te, e.g. trans(x, y, theta)
# Out:
# ⎡  ⎛
# ⎢  ⎜
# ⎢  ⎜       __________________________________________________________
# ⎢  ⎜      ╱                                                        2
# ⎢  ⎜     ╱      ⎛  2     2                   2                   2⎞      ⎛
# ⎢  ⎜    ╱       ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠      ⎜
# ⎢- ⎜   ╱    1 - ──────────────────────────────────────────────────── ⋅sin⎜acos
# ⎢  ⎜  ╱                                  2   2                           ⎜
# ⎢  ⎜╲╱                               4⋅l₁ ⋅l₂                            ⎜
# ⎢  ⎝                                                                     ⎝
# ⎢
# ⎢   ⎛
# ⎢   ⎜
# ⎢   ⎜       __________________________________________________________
# ⎢   ⎜      ╱                                                        2
# ⎢   ⎜     ╱      ⎛  2     2                   2                   2⎞      ⎛
# ⎢   ⎜    ╱       ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠      ⎜
# ⎢ - ⎜   ╱    1 - ──────────────────────────────────────────────────── ⋅sin⎜aco
# ⎢   ⎜  ╱                                  2   2                           ⎜
# ⎢   ⎜╲╱                               4⋅l₁ ⋅l₂                            ⎜
# ⎢   ⎝                                                                     ⎝
# ⎢
# ⎣
#
#
#
#
#
# ⎛  2     2                   2                   2⎞                       ⎞
# ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟
# ⎜─────────────────────────────────────────────────⎟ - atan⎜──────────────⎟⎟ -
# ⎜         _______________________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟
# ⎜        ╱                 2                   2  ⎟                       ⎟
# ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠
#
#
#
#
#
#  ⎛  2     2                   2                   2⎞                       ⎞
#  ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟
# s⎜─────────────────────────────────────────────────⎟ - atan⎜──────────────⎟⎟ -
#  ⎜         _______________________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟
#  ⎜        ╱                 2                   2  ⎟                       ⎟
#  ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠
#
#
#
#                                                        ⎛    ⎛  2     2
# ⎛  2     2                   2                   2⎞    ⎜    ⎜l₁  - l₂  + (-l₃⋅
# ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠⋅cos⎜acos⎜─────────────────
#                                                        ⎜    ⎜         ________
#                                                        ⎜    ⎜        ╱
#                                                        ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅si
# ──────────────────────────────────────────────────────────────────────────────
#                                                                 2⋅l₁⋅l₂
#
#
#
#                                                         ⎛    ⎛  2     2
#  ⎛  2     2                   2                   2⎞    ⎜    ⎜l₁  - l₂  + (-l₃
#  ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠⋅cos⎜acos⎜────────────────
#                                                         ⎜    ⎜         _______
#                                                         ⎜    ⎜        ╱
#                                                         ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅s
#  ─────────────────────────────────────────────────────────────────────────────
#                                                                  2⋅l₁⋅l₂
#
#
#
#
#
#            2                   2⎞                       ⎞⎞
# sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# ────────────────────────────────⎟ - atan⎜──────────────⎟⎟⎟
# _______________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#          2                   2  ⎟                       ⎟⎟    ⎛    ⎛  2     2
# n(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠⎟    ⎜    ⎜l₁  + l₂
# ─────────────────────────────────────────────────────────⎟⋅cos⎜acos⎜──────────
#                                                          ⎟    ⎜    ⎝
#                                                          ⎟    ⎜
#                                                          ⎠    ⎝
#
#             2                   2⎞                       ⎞⎞
# ⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# ─────────────────────────────────⎟ - atan⎜──────────────⎟⎟⎟
# ________________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#           2                   2  ⎟                       ⎟⎟    ⎛    ⎛  2     2
# in(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠⎟    ⎜    ⎜l₁  + l₂
# ──────────────────────────────────────────────────────────⎟⋅sin⎜acos⎜─────────
#                                                           ⎟    ⎜    ⎝
#                                                           ⎟    ⎜
#                                                           ⎠    ⎝
#
#
#
#
#
#
#
#                   2                   2⎞       ⎛  2     2                   2
# - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)
# ───────────────────────────────────────⎟ + acos⎜──────────────────────────────
#            2⋅l₁⋅l₂                     ⎠       ⎜         _____________________
#                                                ⎜        ╱                 2
#                                                ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  +
#
#
#
#
#
#                    2                   2⎞       ⎛  2     2                   2
#  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)
# ────────────────────────────────────────⎟ + acos⎜─────────────────────────────
#             2⋅l₁⋅l₂                     ⎠       ⎜         ____________________
#                                                 ⎜        ╱                 2
#                                                 ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  +
#
#
#
#                                                               ⎛
#                                                               ⎜
#                                                               ⎜         ______
#                                                               ⎜        ╱
#                   2⎞                                      ⎞   ⎜       ╱      ⎛
# + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞       ⎛sin(θ)⎞⎟   ⎜      ╱       ⎝
# ───────────────────⎟ - atan⎜──────────────⎟ + atan⎜──────⎟⎟ - ⎜-    ╱    1 - ─
# __________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠       ⎝cos(θ)⎠⎟   ⎜    ╱
#                 2  ⎟                                      ⎟   ⎜  ╲╱
# (-l₃⋅cos(θ) + x)   ⎠                                      ⎠   ⎝
#
#                                                                ⎛
#                                                                ⎜
#                                                                ⎜       _______
#                                                                ⎜      ╱
#                    2⎞                                      ⎞   ⎜     ╱      ⎛
#  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞       ⎛sin(θ)⎞⎟   ⎜    ╱       ⎝l
# ────────────────────⎟ - atan⎜──────────────⎟ + atan⎜──────⎟⎟ - ⎜   ╱    1 - ──
# ___________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠       ⎝cos(θ)⎠⎟   ⎜  ╱
#                  2  ⎟                                      ⎟   ⎜╲╱
#  (-l₃⋅cos(θ) + x)   ⎠                                      ⎠   ⎝
#
#                                                             0
#
#
#
# ____________________________________________________
#                                                   2
#   2     2                   2                   2⎞      ⎛    ⎛  2     2
# l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠      ⎜    ⎜l₁  - l₂  + (-l₃
# ─────────────────────────────────────────────────── ⋅cos⎜acos⎜────────────────
#                         2   2                           ⎜    ⎜         _______
#                     4⋅l₁ ⋅l₂                            ⎜    ⎜        ╱
#                                                         ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅s
#
#
#
# ___________________________________________________
#                                                  2
#  2     2                   2                   2⎞      ⎛    ⎛  2     2
# ₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠      ⎜    ⎜l₁  - l₂  + (-l₃⋅
# ────────────────────────────────────────────────── ⋅cos⎜acos⎜─────────────────
#                        2   2                           ⎜    ⎜         ________
#                    4⋅l₁ ⋅l₂                            ⎜    ⎜        ╱
#                                                        ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅si
#
#
#
#
#                                                              ⎛  2     2
#                                                              ⎝l₁  + l₂  - (-l₃
#
#             2                   2⎞                       ⎞
# ⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟
# ─────────────────────────────────⎟ - atan⎜──────────────⎟⎟ - ─────────────────
# ________________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟
#           2                   2  ⎟                       ⎟
# in(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠
#
#
#                                                             ⎛  2     2
#                                                             ⎝l₁  + l₂  - (-l₃⋅
#
#            2                   2⎞                       ⎞
# sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟
# ────────────────────────────────⎟ - atan⎜──────────────⎟⎟ + ──────────────────
# _______________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟
#          2                   2  ⎟                       ⎟
# n(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠
#
#
#
#                                       ⎛    ⎛  2     2                   2
#             2                   2⎞    ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-
# ⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠⋅sin⎜acos⎜──────────────────────────────────
#                                       ⎜    ⎜         _________________________
#                                       ⎜    ⎜        ╱                 2
#                                       ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃
# ──────────────────────────────────────────────────────────────────────────────
#                                                2⋅l₁⋅l₂
#
#
#
#                                      ⎛    ⎛  2     2                   2
#            2                   2⎞    ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l
# sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠⋅sin⎜acos⎜───────────────────────────────────
#                                      ⎜    ⎜         __________________________
#                                      ⎜    ⎜        ╱                 2
#                                      ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                               2⋅l₁⋅l₂
#
#
#
#
#
#               2⎞                       ⎞⎞
# l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# ───────────────⎟ - atan⎜──────────────⎟⎟⎟
# ______________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#             2  ⎟                       ⎟⎟    ⎛    ⎛  2     2
# ⋅cos(θ) + x)   ⎠                       ⎠⎟    ⎜    ⎜l₁  + l₂  - (-l₃⋅sin(θ) + y
# ────────────────────────────────────────⎟⋅sin⎜acos⎜───────────────────────────
#                                         ⎟    ⎜    ⎝                     2⋅l₁⋅l
#                                         ⎟    ⎜
#                                         ⎠    ⎝
#
#              2⎞                       ⎞⎞
# ₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# ──────────────⎟ - atan⎜──────────────⎟⎟⎟
# _____________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#            2  ⎟                       ⎟⎟    ⎛    ⎛  2     2
# cos(θ) + x)   ⎠                       ⎠⎟    ⎜    ⎜l₁  + l₂  - (-l₃⋅sin(θ) + y)
# ───────────────────────────────────────⎟⋅cos⎜acos⎜────────────────────────────
#                                        ⎟    ⎜    ⎝                     2⋅l₁⋅l₂
#                                        ⎟    ⎜
#                                        ⎠    ⎝
#
#
#
#
#
#
#
#  2                   2⎞       ⎛  2     2                   2
# )  - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x
# ──────────────────────⎟ + acos⎜───────────────────────────────────────────────
# ₂                     ⎠       ⎜         ______________________________________
#                               ⎜        ╱                 2                   2
#                               ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)
#
#
#
#
#
# 2                   2⎞       ⎛  2     2                   2
#   - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)
# ─────────────────────⎟ + acos⎜────────────────────────────────────────────────
#                      ⎠       ⎜         _______________________________________
#                              ⎜        ╱                 2                   2
#                              ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)
#
#
#
#                                             ⎛
#                                             ⎜
#                                             ⎜       __________________________
#                                             ⎜      ╱
#  2⎞                                      ⎞  ⎜     ╱      ⎛  2     2
# ) ⎟       ⎛-l₃⋅sin(θ) + y⎞       ⎛sin(θ)⎞⎟  ⎜    ╱       ⎝l₁  + l₂  - (-l₃⋅sin
# ──⎟ - atan⎜──────────────⎟ + atan⎜──────⎟⎟  ⎜   ╱    1 - ─────────────────────
# _ ⎟       ⎝-l₃⋅cos(θ) + x⎠       ⎝cos(θ)⎠⎟  ⎜  ╱
#   ⎟                                      ⎟  ⎜╲╱
#   ⎠                                      ⎠  ⎝
#
#                                               ⎛
#                                               ⎜
#                                               ⎜       ________________________
#                                               ⎜      ╱
# 2⎞                                      ⎞     ⎜     ╱      ⎛  2     2
#  ⎟       ⎛-l₃⋅sin(θ) + y⎞       ⎛sin(θ)⎞⎟     ⎜    ╱       ⎝l₁  + l₂  - (-l₃⋅s
# ─⎟ - atan⎜──────────────⎟ + atan⎜──────⎟⎟   - ⎜   ╱    1 - ───────────────────
#  ⎟       ⎝-l₃⋅cos(θ) + x⎠       ⎝cos(θ)⎠⎟     ⎜  ╱
#  ⎟                                      ⎟     ⎜╲╱
#  ⎠                                      ⎠     ⎝
#
#
#
#
#
# ________________________________
#                               2
#         2                   2⎞      ⎛    ⎛  2     2                   2
# (θ) + y)  - (-l₃⋅cos(θ) + x) ⎠      ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃
# ─────────────────────────────── ⋅sin⎜acos⎜────────────────────────────────────
#     2   2                           ⎜    ⎜         ___________________________
# 4⋅l₁ ⋅l₂                            ⎜    ⎜        ╱                 2
#                                     ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅c
#
#
#
# __________________________________
#                                 2
#           2                   2⎞      ⎛    ⎛  2     2                   2
# in(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠      ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-
# ───────────────────────────────── ⋅sin⎜acos⎜──────────────────────────────────
#       2   2                           ⎜    ⎜         _________________________
#   4⋅l₁ ⋅l₂                            ⎜    ⎜        ╱                 2
#                                       ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃
#
#
#
#
#                                          ⎛  2     2                   2
#                                          ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃
#
#             2⎞                       ⎞
# ⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟
# ─────────────⎟ - atan⎜──────────────⎟⎟ - ─────────────────────────────────────
# ____________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟
#           2  ⎟                       ⎟
# os(θ) + x)   ⎠                       ⎠
#
#
#                                            ⎛  2     2                   2
#                                            ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-
#
#               2⎞                       ⎞
# l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟
# ───────────────⎟ - atan⎜──────────────⎟⎟ - ───────────────────────────────────
# ______________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟
#             2  ⎟                       ⎟
# ⋅cos(θ) + x)   ⎠                       ⎠
#
#
#
#                   ⎛    ⎛  2     2                   2                   2⎞
#             2⎞    ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟
# ⋅cos(θ) + x) ⎠⋅cos⎜acos⎜─────────────────────────────────────────────────⎟ - a
#                   ⎜    ⎜         _______________________________________ ⎟
#                   ⎜    ⎜        ╱                 2                   2  ⎟
#                   ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                            2⋅l₁⋅l₂
#
#
#
#                     ⎛    ⎛  2     2                   2                   2⎞
#               2⎞    ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟
# l₃⋅cos(θ) + x) ⎠⋅cos⎜acos⎜─────────────────────────────────────────────────⎟ -
#                     ⎜    ⎜         _______________________________________ ⎟
#                     ⎜    ⎜        ╱                 2                   2  ⎟
#                     ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                              2⋅l₁⋅l₂
#
#
#
#
#
#                    ⎞⎞
#    ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# tan⎜──────────────⎟⎟⎟
#    ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#                    ⎟⎟    ⎛    ⎛  2     2                   2
#                    ⎠⎟    ⎜    ⎜l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x
# ────────────────────⎟⋅sin⎜acos⎜───────────────────────────────────────────────
#                     ⎟    ⎜    ⎝                     2⋅l₁⋅l₂
#                     ⎟    ⎜
#                     ⎠    ⎝
#
#                      ⎞⎞
#      ⎛-l₃⋅sin(θ) + y⎞⎟⎟
#  atan⎜──────────────⎟⎟⎟
#      ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#                      ⎟⎟    ⎛    ⎛  2     2                   2
#                      ⎠⎟    ⎜    ⎜l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) +
# ──────────────────────⎟⋅cos⎜acos⎜─────────────────────────────────────────────
#                       ⎟    ⎜    ⎝                     2⋅l₁⋅l₂
#                       ⎟    ⎜
#                       ⎠    ⎝
#
#
#
#
#
#
#
#  2⎞       ⎛  2     2                   2                   2⎞
# ) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ
# ──⎟ + acos⎜─────────────────────────────────────────────────⎟ - atan⎜─────────
#   ⎠       ⎜         _______________________________________ ⎟       ⎝-l₃⋅cos(θ
#           ⎜        ╱                 2                   2  ⎟
#           ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
#
#
#
#
#
#    2⎞       ⎛  2     2                   2                   2⎞
#  x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin
# ────⎟ + acos⎜─────────────────────────────────────────────────⎟ - atan⎜───────
#     ⎠       ⎜         _______________________________________ ⎟       ⎝-l₃⋅cos
#             ⎜        ╱                 2                   2  ⎟
#             ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
#
#
#
#                          ⎛
#                          ⎜
#                          ⎜         ___________________________________________
#                          ⎜        ╱
#                      ⎞   ⎜       ╱      ⎛  2     2                   2
# ) + y⎞       ⎛sin(θ)⎞⎟   ⎜      ╱       ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅
# ─────⎟ + atan⎜──────⎟⎟ - ⎜-    ╱    1 - ──────────────────────────────────────
# ) + x⎠       ⎝cos(θ)⎠⎟   ⎜    ╱                                  2   2
#                      ⎟   ⎜  ╲╱                               4⋅l₁ ⋅l₂
#                      ⎠   ⎝
#
#                            ⎛
#                            ⎜
#                            ⎜       ___________________________________________
#                            ⎜      ╱
#                        ⎞   ⎜     ╱      ⎛  2     2                   2
# (θ) + y⎞       ⎛sin(θ)⎞⎟   ⎜    ╱       ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅
# ───────⎟ + atan⎜──────⎟⎟ + ⎜   ╱    1 - ──────────────────────────────────────
# (θ) + x⎠       ⎝cos(θ)⎠⎟   ⎜  ╱                                  2   2
#                        ⎟   ⎜╲╱                               4⋅l₁ ⋅l₂
#                        ⎠   ⎝
#
#                         0
#
#
#
# _______________
#              2
#            2⎞      ⎛    ⎛  2     2                   2                   2⎞
# cos(θ) + x) ⎠      ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟
# ────────────── ⋅cos⎜acos⎜─────────────────────────────────────────────────⎟ -
#                    ⎜    ⎜         _______________________________________ ⎟
#                    ⎜    ⎜        ╱                 2                   2  ⎟
#                    ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
#
#
#
# _______________
#              2
#            2⎞      ⎛    ⎛  2     2                   2                   2⎞
# cos(θ) + x) ⎠      ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟
# ────────────── ⋅cos⎜acos⎜─────────────────────────────────────────────────⎟ -
#                    ⎜    ⎜         _______________________________________ ⎟
#                    ⎜    ⎜        ╱                 2                   2  ⎟
#                    ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
#
#
#
#
#                         ⎛  2     2                   2                   2⎞
#                         ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠⋅si
#
#                     ⎞
#     ⎛-l₃⋅sin(θ) + y⎞⎟
# atan⎜──────────────⎟⎟ - ──────────────────────────────────────────────────────
#     ⎝-l₃⋅cos(θ) + x⎠⎟
#                     ⎟
#                     ⎠
#
#
#                         ⎛  2     2                   2                   2⎞
#                         ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠⋅si
#
#                     ⎞
#     ⎛-l₃⋅sin(θ) + y⎞⎟
# atan⎜──────────────⎟⎟ + ──────────────────────────────────────────────────────
#     ⎝-l₃⋅cos(θ) + x⎠⎟
#                     ⎟
#                     ⎠
#
#
#
#  ⎛    ⎛  2     2                   2                   2⎞
#  ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) +
# n⎜acos⎜─────────────────────────────────────────────────⎟ - atan⎜─────────────
#  ⎜    ⎜         _______________________________________ ⎟       ⎝-l₃⋅cos(θ) +
#  ⎜    ⎜        ╱                 2                   2  ⎟
#  ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#           2⋅l₁⋅l₂
#
#
#
#  ⎛    ⎛  2     2                   2                   2⎞
#  ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) +
# n⎜acos⎜─────────────────────────────────────────────────⎟ - atan⎜─────────────
#  ⎜    ⎜         _______________________________________ ⎟       ⎝-l₃⋅cos(θ) +
#  ⎜    ⎜        ╱                 2                   2  ⎟
#  ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#           2⋅l₁⋅l₂
#
#
#
#
#
#   ⎞⎞
# y⎞⎟⎟
# ─⎟⎟⎟
# x⎠⎟⎟
#   ⎟⎟    ⎛    ⎛  2     2                   2                   2⎞       ⎛  2
#   ⎠⎟    ⎜    ⎜l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  -
# ───⎟⋅cos⎜acos⎜─────────────────────────────────────────────────⎟ + acos⎜──────
#    ⎟    ⎜    ⎝                     2⋅l₁⋅l₂                     ⎠       ⎜
#    ⎟    ⎜                                                              ⎜
#    ⎠    ⎝                                                              ⎝ 2⋅l₁⋅
#
#   ⎞⎞
# y⎞⎟⎟
# ─⎟⎟⎟
# x⎠⎟⎟
#   ⎟⎟    ⎛    ⎛  2     2                   2                   2⎞       ⎛  2
#   ⎠⎟    ⎜    ⎜l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  -
# ───⎟⋅sin⎜acos⎜─────────────────────────────────────────────────⎟ + acos⎜──────
#    ⎟    ⎜    ⎝                     2⋅l₁⋅l₂                     ⎠       ⎜
#    ⎟    ⎜                                                              ⎜
#    ⎠    ⎝                                                              ⎝ 2⋅l₁⋅
#
#
#
#
#
#
#
#   2                   2                   2⎞
# l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞       ⎛sin
# ───────────────────────────────────────────⎟ - atan⎜──────────────⎟ + atan⎜───
#    _______________________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠       ⎝cos
#   ╱                 2                   2  ⎟
# ╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
#
#
#
#
#
#   2                   2                   2⎞
# l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞       ⎛sin
# ───────────────────────────────────────────⎟ - atan⎜──────────────⎟ + atan⎜───
#    _______________________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠       ⎝cos
#   ╱                 2                   2  ⎟
# ╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
#
#
#
#
#
#
#
#     ⎞        ⎛    ⎛  2     2                   2                   2⎞
# (θ)⎞⎟        ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-
# ───⎟⎟  l₁⋅cos⎜acos⎜─────────────────────────────────────────────────⎟ - atan⎜─
# (θ)⎠⎟        ⎜    ⎜         _______________________________________ ⎟       ⎝-
#     ⎟        ⎜    ⎜        ╱                 2                   2  ⎟
#     ⎠        ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
#
#
#
#
#
#     ⎞          ⎛    ⎛  2     2                   2                   2⎞
# (θ)⎞⎟          ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟
# ───⎟⎟  - l₁⋅sin⎜acos⎜─────────────────────────────────────────────────⎟ - atan
# (θ)⎠⎟          ⎜    ⎜         _______________________________________ ⎟
#     ⎟          ⎜    ⎜        ╱                 2                   2  ⎟
#     ⎠          ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
#
#
#
#                      ⎛
#                      ⎜
#                      ⎜       _________________________________________________
#                      ⎜      ╱
#               ⎞      ⎜     ╱      ⎛  2     2                   2
# l₃⋅sin(θ) + y⎞⎟      ⎜    ╱       ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ)
# ─────────────⎟⎟ + l₂⋅⎜   ╱    1 - ────────────────────────────────────────────
# l₃⋅cos(θ) + x⎠⎟      ⎜  ╱                                  2   2
#               ⎟      ⎜╲╱                               4⋅l₁ ⋅l₂
#               ⎠      ⎝
#
#                        ⎛
#                        ⎜
#                        ⎜       _______________________________________________
#                        ⎜      ╱
#                 ⎞      ⎜     ╱      ⎛  2     2                   2
# ⎛-l₃⋅sin(θ) + y⎞⎟      ⎜    ╱       ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(
# ⎜──────────────⎟⎟ + l₂⋅⎜   ╱    1 - ──────────────────────────────────────────
# ⎝-l₃⋅cos(θ) + x⎠⎟      ⎜  ╱                                  2   2
#                 ⎟      ⎜╲╱                               4⋅l₁ ⋅l₂
#                 ⎠      ⎝
#
#
#
#
#
# _________
#        2
#      2⎞      ⎛    ⎛  2     2                   2                   2⎞
#  + x) ⎠      ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-
# ──────── ⋅sin⎜acos⎜─────────────────────────────────────────────────⎟ - atan⎜─
#              ⎜    ⎜         _______________________________________ ⎟       ⎝-
#              ⎜    ⎜        ╱                 2                   2  ⎟
#              ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
#
#
#
# ___________
#          2
#        2⎞      ⎛    ⎛  2     2                   2                   2⎞
# θ) + x) ⎠      ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟
# ────────── ⋅cos⎜acos⎜─────────────────────────────────────────────────⎟ - atan
#                ⎜    ⎜         _______________________________________ ⎟
#                ⎜    ⎜        ╱                 2                   2  ⎟
#                ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
#
#
#
#                                                                          ⎛
#                   ⎛  2     2                   2                   2⎞    ⎜
#                   ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠⋅cos⎜acos
#                                                                          ⎜
#               ⎞                                                          ⎜
# l₃⋅sin(θ) + y⎞⎟                                                          ⎝
# ─────────────⎟⎟ - ────────────────────────────────────────────────────────────
# l₃⋅cos(θ) + x⎠⎟
#               ⎟
# ...
#   ⎟
#   ⎠
#
#
#
#                2                   2⎞                       ⎞⎞
# -l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# ────────────────────────────────────⎟ - atan⎜──────────────⎟⎟⎟
# ___________________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#              2                   2  ⎟                       ⎟⎟    ⎛    ⎛  2
# ₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠⎟    ⎜    ⎜l₁  +
# ─────────────────────────────────────────────────────────────⎟⋅cos⎜acos⎜──────
#                                                              ⎟    ⎜    ⎝
#                                                              ⎟    ⎜
#                                                              ⎠    ⎝
#
#                  2                   2⎞                       ⎞⎞
#  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# ──────────────────────────────────────⎟ - atan⎜──────────────⎟⎟⎟
# _____________________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#                2                   2  ⎟                       ⎟⎟    ⎛    ⎛  2
# -l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠⎟    ⎜    ⎜l₁
# ───────────────────────────────────────────────────────────────⎟⋅sin⎜acos⎜────
#                                                                ⎟    ⎜    ⎝
#                                                                ⎟    ⎜
#                                                                ⎠    ⎝
#
#                           1
#
#
#
#
#
#   2                   2                   2⎞       ⎛  2     2
# l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) +
# ───────────────────────────────────────────⎟ + acos⎜──────────────────────────
#                2⋅l₁⋅l₂                     ⎠       ⎜         _________________
#                                                    ⎜        ╱
#                                                    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)
#
#
#
#
#
#     2                   2                   2⎞       ⎛  2     2
# + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ)
# ─────────────────────────────────────────────⎟ + acos⎜────────────────────────
#                  2⋅l₁⋅l₂                     ⎠       ⎜         _______________
#                                                      ⎜        ╱
#                                                      ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) +
#
#
#
#                                                                   ⎛
#                                                                   ⎜
#                                                                   ⎜         __
#                                                                   ⎜        ╱
#   2                   2⎞                                      ⎞   ⎜       ╱
# y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞       ⎛sin(θ)⎞⎟   ⎜      ╱
# ───────────────────────⎟ - atan⎜──────────────⎟ + atan⎜──────⎟⎟ - ⎜-    ╱    1
# ______________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠       ⎝cos(θ)⎠⎟   ⎜    ╱
# 2                   2  ⎟                                      ⎟   ⎜  ╲╱
#   + (-l₃⋅cos(θ) + x)   ⎠                                      ⎠   ⎝
#
#                                                                     ⎛
#                                                                     ⎜
#                                                                     ⎜       __
#                                                                     ⎜      ╱
#     2                   2⎞                                      ⎞   ⎜     ╱
# + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞       ⎛sin(θ)⎞⎟   ⎜    ╱
# ─────────────────────────⎟ - atan⎜──────────────⎟ + atan⎜──────⎟⎟ - ⎜   ╱    1
# ________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠       ⎝cos(θ)⎠⎟   ⎜  ╱
#   2                   2  ⎟                                      ⎟   ⎜╲╱
# y)  + (-l₃⋅cos(θ) + x)   ⎠                                      ⎠   ⎝
#
#
#
#
#
# ________________________________________________________
#                                                       2
#    ⎛  2     2                   2                   2⎞      ⎛    ⎛  2     2
#    ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠      ⎜    ⎜l₁  - l₂  +
#  - ──────────────────────────────────────────────────── ⋅cos⎜acos⎜────────────
#                             2   2                           ⎜    ⎜         ___
#                         4⋅l₁ ⋅l₂                            ⎜    ⎜        ╱
#                                                             ⎝    ⎝ 2⋅l₁⋅╲╱  (-
#
#
#
# ________________________________________________________
#                                                       2
#    ⎛  2     2                   2                   2⎞      ⎛    ⎛  2     2
#    ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠      ⎜    ⎜l₁  - l₂  +
#  - ──────────────────────────────────────────────────── ⋅cos⎜acos⎜────────────
#                             2   2                           ⎜    ⎜         ___
#                         4⋅l₁ ⋅l₂                            ⎜    ⎜        ╱
#                                                             ⎝    ⎝ 2⋅l₁⋅╲╱  (-
#
#
#
#
#                                                                  ⎛  2     2
#                                                                  ⎝l₁  + l₂  -
#
#                 2                   2⎞                       ⎞
# (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟
# ─────────────────────────────────────⎟ - atan⎜──────────────⎟⎟ - ─────────────
# ____________________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟
#               2                   2  ⎟                       ⎟
# l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠
#
#
#                                                                  ⎛  2     2
#                                                                  ⎝l₁  + l₂  -
#
#                 2                   2⎞                       ⎞
# (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟
# ─────────────────────────────────────⎟ - atan⎜──────────────⎟⎟ + ─────────────
# ____________________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟
#               2                   2  ⎟                       ⎟
# l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠
#
#
#
#                                           ⎛    ⎛  2     2                   2
#                 2                   2⎞    ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)
# (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠⋅sin⎜acos⎜──────────────────────────────
#                                           ⎜    ⎜         _____________________
#                                           ⎜    ⎜        ╱                 2
#                                           ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  +
# ──────────────────────────────────────────────────────────────────────────────
#                                                    2⋅l₁⋅l₂
#
#
#
#                                           ⎛    ⎛  2     2                   2
#                 2                   2⎞    ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)
# (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠⋅sin⎜acos⎜──────────────────────────────
#                                           ⎜    ⎜         _____________________
#                                           ⎜    ⎜        ╱                 2
#                                           ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  +
# ──────────────────────────────────────────────────────────────────────────────
#                                                    2⋅l₁⋅l₂
#
#
#
#
#
#                   2⎞                       ⎞⎞
# + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# ───────────────────⎟ - atan⎜──────────────⎟⎟⎟
# __________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#                 2  ⎟                       ⎟⎟    ⎛    ⎛  2     2
# (-l₃⋅cos(θ) + x)   ⎠                       ⎠⎟    ⎜    ⎜l₁  + l₂  - (-l₃⋅sin(θ)
# ────────────────────────────────────────────⎟⋅sin⎜acos⎜───────────────────────
#                                             ⎟    ⎜    ⎝                     2⋅
#                                             ⎟    ⎜
#                                             ⎠    ⎝
#
#                   2⎞                       ⎞⎞
# + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# ───────────────────⎟ - atan⎜──────────────⎟⎟⎟
# __________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#                 2  ⎟                       ⎟⎟    ⎛    ⎛  2     2
# (-l₃⋅cos(θ) + x)   ⎠                       ⎠⎟    ⎜    ⎜l₁  + l₂  - (-l₃⋅sin(θ)
# ────────────────────────────────────────────⎟⋅cos⎜acos⎜───────────────────────
#                                             ⎟    ⎜    ⎝                     2⋅
#                                             ⎟    ⎜
#                                             ⎠    ⎝
#
#
#
#
#
#
#
#      2                   2⎞       ⎛  2     2                   2
#  + y)  - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ)
# ──────────────────────────⎟ + acos⎜───────────────────────────────────────────
# l₁⋅l₂                     ⎠       ⎜         __________________________________
#                                   ⎜        ╱                 2
#                                   ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) +
#
#
#
#
#
#      2                   2⎞       ⎛  2     2                   2
#  + y)  - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ)
# ──────────────────────────⎟ + acos⎜───────────────────────────────────────────
# l₁⋅l₂                     ⎠       ⎜         __________________________________
#                                   ⎜        ╱                 2
#                                   ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) +
#
#
#
#                                               ⎞⎤
#                                               ⎟⎥
#                                               ⎟⎥
#                                               ⎟⎥
#      2⎞                                      ⎞⎟⎥
#  + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞       ⎛sin(θ)⎞⎟⎟⎥
# ──────⎟ - atan⎜──────────────⎟ + atan⎜──────⎟⎟⎟⎥
# _____ ⎟       ⎝-l₃⋅cos(θ) + x⎠       ⎝cos(θ)⎠⎟⎟⎥
#    2  ⎟                                      ⎟⎟⎥
#  x)   ⎠                                      ⎠⎠⎥
#                                                ⎥
#                                               ⎞⎥
#                                               ⎟⎥
#                                               ⎟⎥
#                                               ⎟⎥
#      2⎞                                      ⎞⎟⎥
#  + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞       ⎛sin(θ)⎞⎟⎟⎥
# ──────⎟ - atan⎜──────────────⎟ + atan⎜──────⎟⎟⎟⎥
# _____ ⎟       ⎝-l₃⋅cos(θ) + x⎠       ⎝cos(θ)⎠⎟⎟⎥
#    2  ⎟                                      ⎟⎟⎥
#  x)   ⎠                                      ⎠⎠⎥
#                                                ⎥
#                                                ⎦

# %%
# we could simplify the result, but Sympy can't give result
# simplify(Te_new[0, 0])  # --> cos(theta)

# %%
# simplify(Te_new[1, 0])  # --> sin(theta)

# %%
# simplify(Te_new[0, -1])  # --> x

# %% [markdown]
# ### Test the analytical solution

# %%
from numpy import sin, cos, pi, matrix, random
from math import atan2, acos

T0 = trans(0, 0, 0)
lv = [0, 3, 2, 1]  # length of link, l[0] is ingored
bf = B
for i in range(N):
    bf = bf.subs(l[i + 1], lv[i + 1])

def inverse_kinematics(x_e, y_e, theta_e):
    b = bf.subs(x, x_e).subs(y, y_e).subs(theta, theta_e)
    b = (b.subs('I', 1).subs('pi', pi).tolist())
    b = [float(i[0]) for i in b]
    return b

T = forward_kinematics(T0, lv, random.random(N))
show_robot_arm(T)
@interact(x_e=(0, max_len, 0.1), y_e=(-max_len, max_len, 0.1), theta_e=(-pi, pi, 0.1))
def set_end_effector(x_e=5, y_e=0, theta_e=0):
    b = inverse_kinematics(x_e, y_e, theta_e)
    T = forward_kinematics(T0, lv, b)
    show_robot_arm(T)
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(FloatSlider(value=5.0, description='x_e', max=6.0), FloatSlider(value=0.0, description='…
